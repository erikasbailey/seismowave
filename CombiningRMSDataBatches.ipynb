# %% [markdown]
# This notebook gathers all the seismic data processed through BasicPreprocessing-Batch1.py - BasicPreprocessing-Batch12.py, to create one coherent data set which occupies minimum memory.
#
# BasicPreprocessing-Batch1.py - BasicPreprocessing-Batch12.py created all_data_batch1.pickle - all_data_batch12.pickle and contain sea data and RMS data for all the Italian stations, with four months' worth of data stored in each file for all the stattions. The sea data is incorrect, and as such can be ignored. The error was rectified and the data was processed in a separate script and saved in separate files.

# %% [markdown]
# # Import Libraries

# %%
import pickle
import pandas as pd
import os
from glob import glob

# %% [markdown]
# # Path Definitions

# %%
#Define paths to data and find the files

data_path = "Processed Data"
file_pattern = "all_data_batch*.pickle"

file_list = sorted(glob(os.path.join(data_path, file_pattern)))

# %%
combined_data = []

# %% [markdown]
# # Process Files

# %%
#Process each pickle file

def process_pickle(file_path):
    with open(file_path, 'rb') as file:
        data = pickle.load(file)

    #Data is a dictionary with MultiIndex DataFrames (hierarchical structure of heading)
    processed_frames = {}
    df = data.copy()
    #Remove timezones from datetime to facilitate processing
    df = df.apply(lambda col: col.dt.tz_localize(None) if pd.api.types.is_datetime64tz_dtype(col) else col)

    #Reset index to facilitate merging and have the datecolumn as the index
    df.reset_index(inplace=True)
    
    #Store the data
    processed_frames = {'data': df}
    
    return processed_frames

# %%
#Process files and combine data

def combine_pickle_files(file_list):
    combined_data = []
    for file in file_list:
        print(f"Processing: {file}")
        file_data = process_pickle(file)
        combined_data.append(file_data)
    
    #Merge the data across files. for each key, extract the corresponding data and use pd.concat to merge. reindex the result.
    final_combined_data = {}
    for key in combined_data[0].keys():
        final_combined_data[key] = pd.concat([data[key] for data in combined_data], ignore_index=True)
    
    return final_combined_data

# %%
final_data = combine_pickle_files(file_list)
# Out:
# Processing: Processed Data\all_data_batch1.pickle
# C:\Users\erika\AppData\Local\Temp\ipykernel_14164\2660067755.py:11: DeprecationWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   df = df.apply(lambda col: col.dt.tz_localize(None) if pd.api.types.is_datetime64tz_dtype(col) else col)
# Processing: Processed Data\all_data_batch10.pickle
# C:\Users\erika\AppData\Local\Temp\ipykernel_14164\2660067755.py:11: DeprecationWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   df = df.apply(lambda col: col.dt.tz_localize(None) if pd.api.types.is_datetime64tz_dtype(col) else col)
# Processing: Processed Data\all_data_batch11.pickle
# C:\Users\erika\AppData\Local\Temp\ipykernel_14164\2660067755.py:11: DeprecationWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   df = df.apply(lambda col: col.dt.tz_localize(None) if pd.api.types.is_datetime64tz_dtype(col) else col)
# Processing: Processed Data\all_data_batch12.pickle
# C:\Users\erika\AppData\Local\Temp\ipykernel_14164\2660067755.py:11: DeprecationWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   df = df.apply(lambda col: col.dt.tz_localize(None) if pd.api.types.is_datetime64tz_dtype(col) else col)
# Processing: Processed Data\all_data_batch2.pickle
# C:\Users\erika\AppData\Local\Temp\ipykernel_14164\2660067755.py:11: DeprecationWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   df = df.apply(lambda col: col.dt.tz_localize(None) if pd.api.types.is_datetime64tz_dtype(col) else col)
# Processing: Processed Data\all_data_batch3.pickle
# C:\Users\erika\AppData\Local\Temp\ipykernel_14164\2660067755.py:11: DeprecationWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   df = df.apply(lambda col: col.dt.tz_localize(None) if pd.api.types.is_datetime64tz_dtype(col) else col)
# Processing: Processed Data\all_data_batch4.pickle
# C:\Users\erika\AppData\Local\Temp\ipykernel_14164\2660067755.py:11: DeprecationWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   df = df.apply(lambda col: col.dt.tz_localize(None) if pd.api.types.is_datetime64tz_dtype(col) else col)
# Processing: Processed Data\all_data_batch5.pickle
# C:\Users\erika\AppData\Local\Temp\ipykernel_14164\2660067755.py:11: DeprecationWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   df = df.apply(lambda col: col.dt.tz_localize(None) if pd.api.types.is_datetime64tz_dtype(col) else col)
# Processing: Processed Data\all_data_batch6.pickle
# C:\Users\erika\AppData\Local\Temp\ipykernel_14164\2660067755.py:11: DeprecationWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   df = df.apply(lambda col: col.dt.tz_localize(None) if pd.api.types.is_datetime64tz_dtype(col) else col)
# Processing: Processed Data\all_data_batch7.pickle
# C:\Users\erika\AppData\Local\Temp\ipykernel_14164\2660067755.py:11: DeprecationWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   df = df.apply(lambda col: col.dt.tz_localize(None) if pd.api.types.is_datetime64tz_dtype(col) else col)
# Processing: Processed Data\all_data_batch8.pickle
# C:\Users\erika\AppData\Local\Temp\ipykernel_14164\2660067755.py:11: DeprecationWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   df = df.apply(lambda col: col.dt.tz_localize(None) if pd.api.types.is_datetime64tz_dtype(col) else col)
# Processing: Processed Data\all_data_batch9.pickle
# C:\Users\erika\AppData\Local\Temp\ipykernel_14164\2660067755.py:11: DeprecationWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   df = df.apply(lambda col: col.dt.tz_localize(None) if pd.api.types.is_datetime64tz_dtype(col) else col)

# %%
 print(final_data)
# Out:
# {'data': station                       index          CAVT                              \
# component                                       Z
# freq                                     0.05-0.2      0.2-0.35      0.35-0.5
# 0         2018-01-01 00:00:00+00:00  8.815104e-08  3.130537e-07  3.858233e-07
# 1         2018-01-01 01:00:00+00:00  9.075963e-08  2.701870e-07  3.621845e-07
# 2         2018-01-01 02:00:00+00:00  8.520208e-08  2.473702e-07  3.362727e-07
# 3         2018-01-01 03:00:00+00:00  9.375001e-08  2.212960e-07  2.984257e-07
# 4         2018-01-01 04:00:00+00:00  8.792392e-08  2.167006e-07  2.813728e-07
# ...                             ...           ...           ...           ...
# 36520     2020-12-31 20:00:00+00:00  8.805159e-08  5.173107e-07  4.951484e-07
# 36521     2020-12-31 21:00:00+00:00  8.122070e-08  5.236413e-07  5.062911e-07
# 36522     2020-12-31 22:00:00+00:00  7.401806e-08  4.866576e-07  4.634472e-07
# 36523     2020-12-31 23:00:00+00:00  7.629750e-08  5.090513e-07  4.706459e-07
# 36524     2021-01-01 00:00:00+00:00  4.380724e-08  3.421890e-07  2.938108e-07
#
# station                                                            \
# component
# freq           0.5-0.65      0.65-0.8      0.8-0.95      0.95-1.1
# 0          1.872133e-07  8.724746e-08  5.200551e-08  4.367755e-08
# 1          1.733868e-07  8.228034e-08  6.319814e-08  5.388271e-08
# 2          1.771020e-07  8.291564e-08  5.781828e-08  4.418179e-08
# 3          1.629494e-07  8.144139e-08  5.942720e-08  5.077291e-08
# 4          1.555011e-07  9.039725e-08  6.847554e-08  5.700360e-08
# ...                 ...           ...           ...           ...
# 36520      2.734449e-07  1.621017e-07  1.040141e-07  7.473947e-08
# 36521      2.495162e-07  1.616080e-07  1.000351e-07  7.514235e-08
# 36522      2.445945e-07  1.569378e-07  9.904596e-08  7.602344e-08
# 36523      2.428860e-07  1.578281e-07  1.016258e-07  8.924231e-08
# 36524      1.448229e-07  8.193433e-08  6.812266e-08  2.123964e-08
#
# station                                ...     PZIN                    \
# component                              ...        E
# freq           1.1-1.25      1.25-1.4  ... 0.5-0.65 0.65-0.8 0.8-0.95
# 0          3.129343e-08  2.224997e-08  ...      NaN      NaN      NaN
# 1          3.041222e-08  2.066138e-08  ...      NaN      NaN      NaN
# 2          2.699017e-08  1.816186e-08  ...      NaN      NaN      NaN
# 3          3.026113e-08  2.043267e-08  ...      NaN      NaN      NaN
# 4          3.107457e-08  2.002801e-08  ...      NaN      NaN      NaN
# ...                 ...           ...  ...      ...      ...      ...
# 36520      5.398481e-08  4.164952e-08  ...      NaN      NaN      NaN
# 36521      6.245469e-08  4.425945e-08  ...      NaN      NaN      NaN
# 36522      5.961127e-08  4.892937e-08  ...      NaN      NaN      NaN
# 36523      6.840149e-08  4.805512e-08  ...      NaN      NaN      NaN
# 36524      3.177525e-08  2.567385e-08  ...      NaN      NaN      NaN
#
# station
# component
# freq      0.95-1.1 1.1-1.25 1.25-1.4 1.4-1.55 1.55-1.7 1.7-1.85 1.85-2.0
# 0              NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1              NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2              NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3              NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4              NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...            ...      ...      ...      ...      ...      ...      ...
# 36520          NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 36521          NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 36522          NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 36523          NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 36524          NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# [36525 rows x 547 columns]}

# %%
#Print column headers
for key, df in final_data.items():
    print(f"Columns for key '{key}':")
    for col in df.columns.to_list():
        print(col)
# Out:
# Columns for key 'data':
# ('index', '', '')
# ('CAVT', 'Z', '0.05-0.2')
# ('CAVT', 'Z', '0.2-0.35')
# ('CAVT', 'Z', '0.35-0.5')
# ('CAVT', 'Z', '0.5-0.65')
# ('CAVT', 'Z', '0.65-0.8')
# ('CAVT', 'Z', '0.8-0.95')
# ('CAVT', 'Z', '0.95-1.1')
# ('CAVT', 'Z', '1.1-1.25')
# ('CAVT', 'Z', '1.25-1.4')
# ('CAVT', 'Z', '1.4-1.55')
# ('CAVT', 'Z', '1.55-1.7')
# ('CAVT', 'Z', '1.7-1.85')
# ('CAVT', 'Z', '1.85-2.0')
# ('MMGO', 'Z', '0.05-0.2')
# ('MMGO', 'Z', '0.2-0.35')
# ('MMGO', 'Z', '0.35-0.5')
# ('MMGO', 'Z', '0.5-0.65')
# ('MMGO', 'Z', '0.65-0.8')
# ('MMGO', 'Z', '0.8-0.95')
# ('MMGO', 'Z', '0.95-1.1')
# ('MMGO', 'Z', '1.1-1.25')
# ('MMGO', 'Z', '1.25-1.4')
# ('MMGO', 'Z', '1.4-1.55')
# ('MMGO', 'Z', '1.55-1.7')
# ('MMGO', 'Z', '1.7-1.85')
# ('MMGO', 'Z', '1.85-2.0')
# ('HPAC', 'Z', '0.05-0.2')
# ('HPAC', 'Z', '0.2-0.35')
# ('HPAC', 'Z', '0.35-0.5')
# ('HPAC', 'Z', '0.5-0.65')
# ('HPAC', 'Z', '0.65-0.8')
# ('HPAC', 'Z', '0.8-0.95')
# ('HPAC', 'Z', '0.95-1.1')
# ('HPAC', 'Z', '1.1-1.25')
# ('HPAC', 'Z', '1.25-1.4')
# ('HPAC', 'Z', '1.4-1.55')
# ('HPAC', 'Z', '1.55-1.7')
# ('HPAC', 'Z', '1.7-1.85')
# ('HPAC', 'Z', '1.85-2.0')
# ('HAGA', 'Z', '0.05-0.2')
# ('HAGA', 'Z', '0.2-0.35')
# ('HAGA', 'Z', '0.35-0.5')
# ('HAGA', 'Z', '0.5-0.65')
# ('HAGA', 'Z', '0.65-0.8')
# ('HAGA', 'Z', '0.8-0.95')
# ('HAGA', 'Z', '0.95-1.1')
# ('HAGA', 'Z', '1.1-1.25')
# ('HAGA', 'Z', '1.25-1.4')
# ('HAGA', 'Z', '1.4-1.55')
# ('HAGA', 'Z', '1.55-1.7')
# ('HAGA', 'Z', '1.7-1.85')
# ('HAGA', 'Z', '1.85-2.0')
# ('SOLUN', 'Z', '0.05-0.2')
# ('SOLUN', 'Z', '0.2-0.35')
# ('SOLUN', 'Z', '0.35-0.5')
# ('SOLUN', 'Z', '0.5-0.65')
# ('SOLUN', 'Z', '0.65-0.8')
# ('SOLUN', 'Z', '0.8-0.95')
# ('SOLUN', 'Z', '0.95-1.1')
# ('SOLUN', 'Z', '1.1-1.25')
# ('SOLUN', 'Z', '1.25-1.4')
# ('SOLUN', 'Z', '1.4-1.55')
# ('SOLUN', 'Z', '1.55-1.7')
# ('SOLUN', 'Z', '1.7-1.85')
# ('SOLUN', 'Z', '1.85-2.0')
# ('CSLB', 'Z', '0.05-0.2')
# ('CSLB', 'Z', '0.2-0.35')
# ('CSLB', 'Z', '0.35-0.5')
# ('CSLB', 'Z', '0.5-0.65')
# ('CSLB', 'Z', '0.65-0.8')
# ('CSLB', 'Z', '0.8-0.95')
# ('CSLB', 'Z', '0.95-1.1')
# ('CSLB', 'Z', '1.1-1.25')
# ('CSLB', 'Z', '1.25-1.4')
# ('CSLB', 'Z', '1.4-1.55')
# ('CSLB', 'Z', '1.55-1.7')
# ('CSLB', 'Z', '1.7-1.85')
# ('CSLB', 'Z', '1.85-2.0')
# ('MUCR', 'Z', '0.05-0.2')
# ('MUCR', 'Z', '0.2-0.35')
# ('MUCR', 'Z', '0.35-0.5')
# ('MUCR', 'Z', '0.5-0.65')
# ('MUCR', 'Z', '0.65-0.8')
# ('MUCR', 'Z', '0.8-0.95')
# ('MUCR', 'Z', '0.95-1.1')
# ('MUCR', 'Z', '1.1-1.25')
# ('MUCR', 'Z', '1.25-1.4')
# ('MUCR', 'Z', '1.4-1.55')
# ('MUCR', 'Z', '1.55-1.7')
# ('MUCR', 'Z', '1.7-1.85')
# ('MUCR', 'Z', '1.85-2.0')
# ('MSRU', 'Z', '0.05-0.2')
# ('MSRU', 'Z', '0.2-0.35')
# ('MSRU', 'Z', '0.35-0.5')
# ('MSRU', 'Z', '0.5-0.65')
# ('MSRU', 'Z', '0.65-0.8')
# ('MSRU', 'Z', '0.8-0.95')
# ('MSRU', 'Z', '0.95-1.1')
# ('MSRU', 'Z', '1.1-1.25')
# ('MSRU', 'Z', '1.25-1.4')
# ('MSRU', 'Z', '1.4-1.55')
# ('MSRU', 'Z', '1.55-1.7')
# ('MSRU', 'Z', '1.7-1.85')
# ('MSRU', 'Z', '1.85-2.0')
# ('AIO', 'Z', '0.05-0.2')
# ('AIO', 'Z', '0.2-0.35')
# ('AIO', 'Z', '0.35-0.5')
# ('AIO', 'Z', '0.5-0.65')
# ('AIO', 'Z', '0.65-0.8')
# ('AIO', 'Z', '0.8-0.95')
# ('AIO', 'Z', '0.95-1.1')
# ('AIO', 'Z', '1.1-1.25')
# ('AIO', 'Z', '1.25-1.4')
# ('AIO', 'Z', '1.4-1.55')
# ('AIO', 'Z', '1.55-1.7')
# ('AIO', 'Z', '1.7-1.85')
# ('AIO', 'Z', '1.85-2.0')
# ('MSDA', 'Z', '0.05-0.2')
# ('MSDA', 'Z', '0.2-0.35')
# ('MSDA', 'Z', '0.35-0.5')
# ('MSDA', 'Z', '0.5-0.65')
# ('MSDA', 'Z', '0.65-0.8')
# ('MSDA', 'Z', '0.8-0.95')
# ('MSDA', 'Z', '0.95-1.1')
# ('MSDA', 'Z', '1.1-1.25')
# ('MSDA', 'Z', '1.25-1.4')
# ('MSDA', 'Z', '1.4-1.55')
# ('MSDA', 'Z', '1.55-1.7')
# ('MSDA', 'Z', '1.7-1.85')
# ('MSDA', 'Z', '1.85-2.0')
# ('WDD', 'Z', '0.05-0.2')
# ('WDD', 'Z', '0.2-0.35')
# ('WDD', 'Z', '0.35-0.5')
# ('WDD', 'Z', '0.5-0.65')
# ('WDD', 'Z', '0.65-0.8')
# ('WDD', 'Z', '0.8-0.95')
# ('WDD', 'Z', '0.95-1.1')
# ('WDD', 'Z', '1.1-1.25')
# ('WDD', 'Z', '1.25-1.4')
# ('WDD', 'Z', '1.4-1.55')
# ('WDD', 'Z', '1.55-1.7')
# ('WDD', 'Z', '1.7-1.85')
# ('WDD', 'Z', '1.85-2.0')
# ('CAVT', 'N', '0.05-0.2')
# ('CAVT', 'N', '0.2-0.35')
# ('CAVT', 'N', '0.35-0.5')
# ('CAVT', 'N', '0.5-0.65')
# ('CAVT', 'N', '0.65-0.8')
# ('CAVT', 'N', '0.8-0.95')
# ('CAVT', 'N', '0.95-1.1')
# ('CAVT', 'N', '1.1-1.25')
# ('CAVT', 'N', '1.25-1.4')
# ('CAVT', 'N', '1.4-1.55')
# ('CAVT', 'N', '1.55-1.7')
# ('CAVT', 'N', '1.7-1.85')
# ('CAVT', 'N', '1.85-2.0')
# ('MMGO', 'N', '0.05-0.2')
# ('MMGO', 'N', '0.2-0.35')
# ('MMGO', 'N', '0.35-0.5')
# ('MMGO', 'N', '0.5-0.65')
# ('MMGO', 'N', '0.65-0.8')
# ('MMGO', 'N', '0.8-0.95')
# ('MMGO', 'N', '0.95-1.1')
# ('MMGO', 'N', '1.1-1.25')
# ('MMGO', 'N', '1.25-1.4')
# ('MMGO', 'N', '1.4-1.55')
# ('MMGO', 'N', '1.55-1.7')
# ('MMGO', 'N', '1.7-1.85')
# ('MMGO', 'N', '1.85-2.0')
# ('HPAC', 'N', '0.05-0.2')
# ('HPAC', 'N', '0.2-0.35')
# ('HPAC', 'N', '0.35-0.5')
# ('HPAC', 'N', '0.5-0.65')
# ('HPAC', 'N', '0.65-0.8')
# ('HPAC', 'N', '0.8-0.95')
# ('HPAC', 'N', '0.95-1.1')
# ('HPAC', 'N', '1.1-1.25')
# ('HPAC', 'N', '1.25-1.4')
# ('HPAC', 'N', '1.4-1.55')
# ('HPAC', 'N', '1.55-1.7')
# ('HPAC', 'N', '1.7-1.85')
# ('HPAC', 'N', '1.85-2.0')
# ('HAGA', 'N', '0.05-0.2')
# ('HAGA', 'N', '0.2-0.35')
# ('HAGA', 'N', '0.35-0.5')
# ('HAGA', 'N', '0.5-0.65')
# ('HAGA', 'N', '0.65-0.8')
# ('HAGA', 'N', '0.8-0.95')
# ('HAGA', 'N', '0.95-1.1')
# ('HAGA', 'N', '1.1-1.25')
# ('HAGA', 'N', '1.25-1.4')
# ('HAGA', 'N', '1.4-1.55')
# ('HAGA', 'N', '1.55-1.7')
# ('HAGA', 'N', '1.7-1.85')
# ('HAGA', 'N', '1.85-2.0')
# ('SOLUN', 'N', '0.05-0.2')
# ('SOLUN', 'N', '0.2-0.35')
# ('SOLUN', 'N', '0.35-0.5')
# ('SOLUN', 'N', '0.5-0.65')
# ('SOLUN', 'N', '0.65-0.8')
# ('SOLUN', 'N', '0.8-0.95')
# ('SOLUN', 'N', '0.95-1.1')
# ('SOLUN', 'N', '1.1-1.25')
# ('SOLUN', 'N', '1.25-1.4')
# ('SOLUN', 'N', '1.4-1.55')
# ('SOLUN', 'N', '1.55-1.7')
# ('SOLUN', 'N', '1.7-1.85')
# ('SOLUN', 'N', '1.85-2.0')
# ('CSLB', 'N', '0.05-0.2')
# ('CSLB', 'N', '0.2-0.35')
# ('CSLB', 'N', '0.35-0.5')
# ('CSLB', 'N', '0.5-0.65')
# ('CSLB', 'N', '0.65-0.8')
# ('CSLB', 'N', '0.8-0.95')
# ('CSLB', 'N', '0.95-1.1')
# ('CSLB', 'N', '1.1-1.25')
# ('CSLB', 'N', '1.25-1.4')
# ('CSLB', 'N', '1.4-1.55')
# ('CSLB', 'N', '1.55-1.7')
# ('CSLB', 'N', '1.7-1.85')
# ('CSLB', 'N', '1.85-2.0')
# ('MUCR', 'N', '0.05-0.2')
# ('MUCR', 'N', '0.2-0.35')
# ('MUCR', 'N', '0.35-0.5')
# ('MUCR', 'N', '0.5-0.65')
# ('MUCR', 'N', '0.65-0.8')
# ('MUCR', 'N', '0.8-0.95')
# ('MUCR', 'N', '0.95-1.1')
# ('MUCR', 'N', '1.1-1.25')
# ('MUCR', 'N', '1.25-1.4')
# ('MUCR', 'N', '1.4-1.55')
# ('MUCR', 'N', '1.55-1.7')
# ('MUCR', 'N', '1.7-1.85')
# ('MUCR', 'N', '1.85-2.0')
# ('MSRU', 'N', '0.05-0.2')
# ('MSRU', 'N', '0.2-0.35')
# ('MSRU', 'N', '0.35-0.5')
# ('MSRU', 'N', '0.5-0.65')
# ('MSRU', 'N', '0.65-0.8')
# ('MSRU', 'N', '0.8-0.95')
# ('MSRU', 'N', '0.95-1.1')
# ('MSRU', 'N', '1.1-1.25')
# ('MSRU', 'N', '1.25-1.4')
# ('MSRU', 'N', '1.4-1.55')
# ('MSRU', 'N', '1.55-1.7')
# ('MSRU', 'N', '1.7-1.85')
# ('MSRU', 'N', '1.85-2.0')
# ('AIO', 'N', '0.05-0.2')
# ('AIO', 'N', '0.2-0.35')
# ('AIO', 'N', '0.35-0.5')
# ('AIO', 'N', '0.5-0.65')
# ('AIO', 'N', '0.65-0.8')
# ('AIO', 'N', '0.8-0.95')
# ('AIO', 'N', '0.95-1.1')
# ('AIO', 'N', '1.1-1.25')
# ('AIO', 'N', '1.25-1.4')
# ('AIO', 'N', '1.4-1.55')
# ('AIO', 'N', '1.55-1.7')
# ('AIO', 'N', '1.7-1.85')
# ('AIO', 'N', '1.85-2.0')
# ('MSDA', 'N', '0.05-0.2')
# ('MSDA', 'N', '0.2-0.35')
# ('MSDA', 'N', '0.35-0.5')
# ('MSDA', 'N', '0.5-0.65')
# ('MSDA', 'N', '0.65-0.8')
# ('MSDA', 'N', '0.8-0.95')
# ('MSDA', 'N', '0.95-1.1')
# ('MSDA', 'N', '1.1-1.25')
# ('MSDA', 'N', '1.25-1.4')
# ('MSDA', 'N', '1.4-1.55')
# ('MSDA', 'N', '1.55-1.7')
# ('MSDA', 'N', '1.7-1.85')
# ('MSDA', 'N', '1.85-2.0')
# ('WDD', 'N', '0.05-0.2')
# ('WDD', 'N', '0.2-0.35')
# ('WDD', 'N', '0.35-0.5')
# ('WDD', 'N', '0.5-0.65')
# ('WDD', 'N', '0.65-0.8')
# ('WDD', 'N', '0.8-0.95')
# ('WDD', 'N', '0.95-1.1')
# ('WDD', 'N', '1.1-1.25')
# ('WDD', 'N', '1.25-1.4')
# ('WDD', 'N', '1.4-1.55')
# ('WDD', 'N', '1.55-1.7')
# ('WDD', 'N', '1.7-1.85')
# ('WDD', 'N', '1.85-2.0')
# ('CAVT', 'E', '0.05-0.2')
# ('CAVT', 'E', '0.2-0.35')
# ('CAVT', 'E', '0.35-0.5')
# ('CAVT', 'E', '0.5-0.65')
# ('CAVT', 'E', '0.65-0.8')
# ('CAVT', 'E', '0.8-0.95')
# ('CAVT', 'E', '0.95-1.1')
# ('CAVT', 'E', '1.1-1.25')
# ('CAVT', 'E', '1.25-1.4')
# ('CAVT', 'E', '1.4-1.55')
# ('CAVT', 'E', '1.55-1.7')
# ('CAVT', 'E', '1.7-1.85')
# ('CAVT', 'E', '1.85-2.0')
# ('MMGO', 'E', '0.05-0.2')
# ('MMGO', 'E', '0.2-0.35')
# ('MMGO', 'E', '0.35-0.5')
# ('MMGO', 'E', '0.5-0.65')
# ('MMGO', 'E', '0.65-0.8')
# ('MMGO', 'E', '0.8-0.95')
# ('MMGO', 'E', '0.95-1.1')
# ('MMGO', 'E', '1.1-1.25')
# ('MMGO', 'E', '1.25-1.4')
# ('MMGO', 'E', '1.4-1.55')
# ('MMGO', 'E', '1.55-1.7')
# ('MMGO', 'E', '1.7-1.85')
# ('MMGO', 'E', '1.85-2.0')
# ('HPAC', 'E', '0.05-0.2')
# ('HPAC', 'E', '0.2-0.35')
# ('HPAC', 'E', '0.35-0.5')
# ('HPAC', 'E', '0.5-0.65')
# ('HPAC', 'E', '0.65-0.8')
# ('HPAC', 'E', '0.8-0.95')
# ('HPAC', 'E', '0.95-1.1')
# ('HPAC', 'E', '1.1-1.25')
# ('HPAC', 'E', '1.25-1.4')
# ('HPAC', 'E', '1.4-1.55')
# ('HPAC', 'E', '1.55-1.7')
# ('HPAC', 'E', '1.7-1.85')
# ('HPAC', 'E', '1.85-2.0')
# ('HAGA', 'E', '0.05-0.2')
# ('HAGA', 'E', '0.2-0.35')
# ('HAGA', 'E', '0.35-0.5')
# ('HAGA', 'E', '0.5-0.65')
# ('HAGA', 'E', '0.65-0.8')
# ('HAGA', 'E', '0.8-0.95')
# ('HAGA', 'E', '0.95-1.1')
# ('HAGA', 'E', '1.1-1.25')
# ('HAGA', 'E', '1.25-1.4')
# ('HAGA', 'E', '1.4-1.55')
# ('HAGA', 'E', '1.55-1.7')
# ('HAGA', 'E', '1.7-1.85')
# ('HAGA', 'E', '1.85-2.0')
# ('SOLUN', 'E', '0.05-0.2')
# ('SOLUN', 'E', '0.2-0.35')
# ('SOLUN', 'E', '0.35-0.5')
# ('SOLUN', 'E', '0.5-0.65')
# ('SOLUN', 'E', '0.65-0.8')
# ('SOLUN', 'E', '0.8-0.95')
# ('SOLUN', 'E', '0.95-1.1')
# ('SOLUN', 'E', '1.1-1.25')
# ('SOLUN', 'E', '1.25-1.4')
# ('SOLUN', 'E', '1.4-1.55')
# ('SOLUN', 'E', '1.55-1.7')
# ('SOLUN', 'E', '1.7-1.85')
# ('SOLUN', 'E', '1.85-2.0')
# ('CSLB', 'E', '0.05-0.2')
# ('CSLB', 'E', '0.2-0.35')
# ('CSLB', 'E', '0.35-0.5')
# ('CSLB', 'E', '0.5-0.65')
# ('CSLB', 'E', '0.65-0.8')
# ('CSLB', 'E', '0.8-0.95')
# ('CSLB', 'E', '0.95-1.1')
# ('CSLB', 'E', '1.1-1.25')
# ('CSLB', 'E', '1.25-1.4')
# ('CSLB', 'E', '1.4-1.55')
# ('CSLB', 'E', '1.55-1.7')
# ('CSLB', 'E', '1.7-1.85')
# ('CSLB', 'E', '1.85-2.0')
# ('MUCR', 'E', '0.05-0.2')
# ('MUCR', 'E', '0.2-0.35')
# ('MUCR', 'E', '0.35-0.5')
# ('MUCR', 'E', '0.5-0.65')
# ('MUCR', 'E', '0.65-0.8')
# ('MUCR', 'E', '0.8-0.95')
# ('MUCR', 'E', '0.95-1.1')
# ('MUCR', 'E', '1.1-1.25')
# ('MUCR', 'E', '1.25-1.4')
# ('MUCR', 'E', '1.4-1.55')
# ('MUCR', 'E', '1.55-1.7')
# ('MUCR', 'E', '1.7-1.85')
# ('MUCR', 'E', '1.85-2.0')
# ('MSRU', 'E', '0.05-0.2')
# ('MSRU', 'E', '0.2-0.35')
# ('MSRU', 'E', '0.35-0.5')
# ('MSRU', 'E', '0.5-0.65')
# ('MSRU', 'E', '0.65-0.8')
# ('MSRU', 'E', '0.8-0.95')
# ('MSRU', 'E', '0.95-1.1')
# ('MSRU', 'E', '1.1-1.25')
# ('MSRU', 'E', '1.25-1.4')
# ('MSRU', 'E', '1.4-1.55')
# ('MSRU', 'E', '1.55-1.7')
# ('MSRU', 'E', '1.7-1.85')
# ('MSRU', 'E', '1.85-2.0')
# ('AIO', 'E', '0.05-0.2')
# ('AIO', 'E', '0.2-0.35')
# ('AIO', 'E', '0.35-0.5')
# ('AIO', 'E', '0.5-0.65')
# ('AIO', 'E', '0.65-0.8')
# ('AIO', 'E', '0.8-0.95')
# ('AIO', 'E', '0.95-1.1')
# ('AIO', 'E', '1.1-1.25')
# ('AIO', 'E', '1.25-1.4')
# ('AIO', 'E', '1.4-1.55')
# ('AIO', 'E', '1.55-1.7')
# ('AIO', 'E', '1.7-1.85')
# ('AIO', 'E', '1.85-2.0')
# ('MSDA', 'E', '0.05-0.2')
# ('MSDA', 'E', '0.2-0.35')
# ('MSDA', 'E', '0.35-0.5')
# ('MSDA', 'E', '0.5-0.65')
# ('MSDA', 'E', '0.65-0.8')
# ('MSDA', 'E', '0.8-0.95')
# ('MSDA', 'E', '0.95-1.1')
# ('MSDA', 'E', '1.1-1.25')
# ('MSDA', 'E', '1.25-1.4')
# ('MSDA', 'E', '1.4-1.55')
# ('MSDA', 'E', '1.55-1.7')
# ('MSDA', 'E', '1.7-1.85')
# ('MSDA', 'E', '1.85-2.0')
# ('WDD', 'E', '0.05-0.2')
# ('WDD', 'E', '0.2-0.35')
# ('WDD', 'E', '0.35-0.5')
# ('WDD', 'E', '0.5-0.65')
# ('WDD', 'E', '0.65-0.8')
# ('WDD', 'E', '0.8-0.95')
# ('WDD', 'E', '0.95-1.1')
# ('WDD', 'E', '1.1-1.25')
# ('WDD', 'E', '1.25-1.4')
# ('WDD', 'E', '1.4-1.55')
# ('WDD', 'E', '1.55-1.7')
# ('WDD', 'E', '1.7-1.85')
# ('WDD', 'E', '1.85-2.0')
# ('MPNC', 'Z', '0.05-0.2')
# ('MPNC', 'Z', '0.2-0.35')
# ('MPNC', 'Z', '0.35-0.5')
# ('MPNC', 'Z', '0.5-0.65')
# ('MPNC', 'Z', '0.65-0.8')
# ('MPNC', 'Z', '0.8-0.95')
# ('MPNC', 'Z', '0.95-1.1')
# ('MPNC', 'Z', '1.1-1.25')
# ('MPNC', 'Z', '1.25-1.4')
# ('MPNC', 'Z', '1.4-1.55')
# ('MPNC', 'Z', '1.55-1.7')
# ('MPNC', 'Z', '1.7-1.85')
# ('MPNC', 'Z', '1.85-2.0')
# ('MPNC', 'N', '0.05-0.2')
# ('MPNC', 'N', '0.2-0.35')
# ('MPNC', 'N', '0.35-0.5')
# ('MPNC', 'N', '0.5-0.65')
# ('MPNC', 'N', '0.65-0.8')
# ('MPNC', 'N', '0.8-0.95')
# ('MPNC', 'N', '0.95-1.1')
# ('MPNC', 'N', '1.1-1.25')
# ('MPNC', 'N', '1.25-1.4')
# ('MPNC', 'N', '1.4-1.55')
# ('MPNC', 'N', '1.55-1.7')
# ('MPNC', 'N', '1.7-1.85')
# ('MPNC', 'N', '1.85-2.0')
# ('MPNC', 'E', '0.05-0.2')
# ('MPNC', 'E', '0.2-0.35')
# ('MPNC', 'E', '0.35-0.5')
# ('MPNC', 'E', '0.5-0.65')
# ('MPNC', 'E', '0.65-0.8')
# ('MPNC', 'E', '0.8-0.95')
# ('MPNC', 'E', '0.95-1.1')
# ('MPNC', 'E', '1.1-1.25')
# ('MPNC', 'E', '1.25-1.4')
# ('MPNC', 'E', '1.4-1.55')
# ('MPNC', 'E', '1.55-1.7')
# ('MPNC', 'E', '1.7-1.85')
# ('MPNC', 'E', '1.85-2.0')
# ('CLTA', 'Z', '0.05-0.2')
# ('CLTA', 'Z', '0.2-0.35')
# ('CLTA', 'Z', '0.35-0.5')
# ('CLTA', 'Z', '0.5-0.65')
# ('CLTA', 'Z', '0.65-0.8')
# ('CLTA', 'Z', '0.8-0.95')
# ('CLTA', 'Z', '0.95-1.1')
# ('CLTA', 'Z', '1.1-1.25')
# ('CLTA', 'Z', '1.25-1.4')
# ('CLTA', 'Z', '1.4-1.55')
# ('CLTA', 'Z', '1.55-1.7')
# ('CLTA', 'Z', '1.7-1.85')
# ('CLTA', 'Z', '1.85-2.0')
# ('CLTA', 'N', '0.05-0.2')
# ('CLTA', 'N', '0.2-0.35')
# ('CLTA', 'N', '0.35-0.5')
# ('CLTA', 'N', '0.5-0.65')
# ('CLTA', 'N', '0.65-0.8')
# ('CLTA', 'N', '0.8-0.95')
# ('CLTA', 'N', '0.95-1.1')
# ('CLTA', 'N', '1.1-1.25')
# ('CLTA', 'N', '1.25-1.4')
# ('CLTA', 'N', '1.4-1.55')
# ('CLTA', 'N', '1.55-1.7')
# ('CLTA', 'N', '1.7-1.85')
# ('CLTA', 'N', '1.85-2.0')
# ('CLTA', 'E', '0.05-0.2')
# ('CLTA', 'E', '0.2-0.35')
# ('CLTA', 'E', '0.35-0.5')
# ('CLTA', 'E', '0.5-0.65')
# ('CLTA', 'E', '0.65-0.8')
# ('CLTA', 'E', '0.8-0.95')
# ('CLTA', 'E', '0.95-1.1')
# ('CLTA', 'E', '1.1-1.25')
# ('CLTA', 'E', '1.25-1.4')
# ('CLTA', 'E', '1.4-1.55')
# ('CLTA', 'E', '1.55-1.7')
# ('CLTA', 'E', '1.7-1.85')
# ('CLTA', 'E', '1.85-2.0')
# ('PZIN', 'Z', '0.05-0.2')
# ('PZIN', 'Z', '0.2-0.35')
# ('PZIN', 'Z', '0.35-0.5')
# ('PZIN', 'Z', '0.5-0.65')
# ('PZIN', 'Z', '0.65-0.8')
# ('PZIN', 'Z', '0.8-0.95')
# ('PZIN', 'Z', '0.95-1.1')
# ('PZIN', 'Z', '1.1-1.25')
# ('PZIN', 'Z', '1.25-1.4')
# ('PZIN', 'Z', '1.4-1.55')
# ('PZIN', 'Z', '1.55-1.7')
# ('PZIN', 'Z', '1.7-1.85')
# ('PZIN', 'Z', '1.85-2.0')
# ('PZIN', 'N', '0.05-0.2')
# ('PZIN', 'N', '0.2-0.35')
# ('PZIN', 'N', '0.35-0.5')
# ('PZIN', 'N', '0.5-0.65')
# ('PZIN', 'N', '0.65-0.8')
# ('PZIN', 'N', '0.8-0.95')
# ('PZIN', 'N', '0.95-1.1')
# ('PZIN', 'N', '1.1-1.25')
# ('PZIN', 'N', '1.25-1.4')
# ('PZIN', 'N', '1.4-1.55')
# ('PZIN', 'N', '1.55-1.7')
# ('PZIN', 'N', '1.7-1.85')
# ('PZIN', 'N', '1.85-2.0')
# ('PZIN', 'E', '0.05-0.2')
# ('PZIN', 'E', '0.2-0.35')
# ('PZIN', 'E', '0.35-0.5')
# ('PZIN', 'E', '0.5-0.65')
# ('PZIN', 'E', '0.65-0.8')
# ('PZIN', 'E', '0.8-0.95')
# ('PZIN', 'E', '0.95-1.1')
# ('PZIN', 'E', '1.1-1.25')
# ('PZIN', 'E', '1.25-1.4')
# ('PZIN', 'E', '1.4-1.55')
# ('PZIN', 'E', '1.55-1.7')
# ('PZIN', 'E', '1.7-1.85')
# ('PZIN', 'E', '1.85-2.0')

# %%
df.columns = ['/'.join(col) for col in df.columns]

# %%
print(df.columns)
# Out:
# Index(['index//', 'CAVT/Z/0.05-0.2', 'CAVT/Z/0.2-0.35', 'CAVT/Z/0.35-0.5',
#        'CAVT/Z/0.5-0.65', 'CAVT/Z/0.65-0.8', 'CAVT/Z/0.8-0.95',
#        'CAVT/Z/0.95-1.1', 'CAVT/Z/1.1-1.25', 'CAVT/Z/1.25-1.4',
#        ...
#        'PZIN/E/0.5-0.65', 'PZIN/E/0.65-0.8', 'PZIN/E/0.8-0.95',
#        'PZIN/E/0.95-1.1', 'PZIN/E/1.1-1.25', 'PZIN/E/1.25-1.4',
#        'PZIN/E/1.4-1.55', 'PZIN/E/1.55-1.7', 'PZIN/E/1.7-1.85',
#        'PZIN/E/1.85-2.0'],
#       dtype='object', length=547)

# %%
print(df)
# Out:
#                         index//  CAVT/Z/0.05-0.2  CAVT/Z/0.2-0.35  \
# 0     2018-01-01 00:00:00+00:00     8.815104e-08     3.130537e-07
# 1     2018-01-01 01:00:00+00:00     9.075963e-08     2.701870e-07
# 2     2018-01-01 02:00:00+00:00     8.520208e-08     2.473702e-07
# 3     2018-01-01 03:00:00+00:00     9.375001e-08     2.212960e-07
# 4     2018-01-01 04:00:00+00:00     8.792392e-08     2.167006e-07
# ...                         ...              ...              ...
# 36520 2020-12-31 20:00:00+00:00     8.805159e-08     5.173107e-07
# 36521 2020-12-31 21:00:00+00:00     8.122070e-08     5.236413e-07
# 36522 2020-12-31 22:00:00+00:00     7.401806e-08     4.866576e-07
# 36523 2020-12-31 23:00:00+00:00     7.629750e-08     5.090513e-07
# 36524 2021-01-01 00:00:00+00:00     4.380724e-08     3.421890e-07
#
#        CAVT/Z/0.35-0.5  CAVT/Z/0.5-0.65  CAVT/Z/0.65-0.8  CAVT/Z/0.8-0.95  \
# 0         3.858233e-07     1.872133e-07     8.724746e-08     5.200551e-08
# 1         3.621845e-07     1.733868e-07     8.228034e-08     6.319814e-08
# 2         3.362727e-07     1.771020e-07     8.291564e-08     5.781828e-08
# 3         2.984257e-07     1.629494e-07     8.144139e-08     5.942720e-08
# 4         2.813728e-07     1.555011e-07     9.039725e-08     6.847554e-08
# ...                ...              ...              ...              ...
# 36520     4.951484e-07     2.734449e-07     1.621017e-07     1.040141e-07
# 36521     5.062911e-07     2.495162e-07     1.616080e-07     1.000351e-07
# 36522     4.634472e-07     2.445945e-07     1.569378e-07     9.904596e-08
# 36523     4.706459e-07     2.428860e-07     1.578281e-07     1.016258e-07
# 36524     2.938108e-07     1.448229e-07     8.193433e-08     6.812266e-08
#
#        CAVT/Z/0.95-1.1  CAVT/Z/1.1-1.25  CAVT/Z/1.25-1.4  ...  \
# 0         4.367755e-08     3.129343e-08     2.224997e-08  ...
# 1         5.388271e-08     3.041222e-08     2.066138e-08  ...
# 2         4.418179e-08     2.699017e-08     1.816186e-08  ...
# 3         5.077291e-08     3.026113e-08     2.043267e-08  ...
# 4         5.700360e-08     3.107457e-08     2.002801e-08  ...
# ...                ...              ...              ...  ...
# 36520     7.473947e-08     5.398481e-08     4.164952e-08  ...
# 36521     7.514235e-08     6.245469e-08     4.425945e-08  ...
# 36522     7.602344e-08     5.961127e-08     4.892937e-08  ...
# 36523     8.924231e-08     6.840149e-08     4.805512e-08  ...
# 36524     2.123964e-08     3.177525e-08     2.567385e-08  ...
#
#        PZIN/E/0.5-0.65  PZIN/E/0.65-0.8  PZIN/E/0.8-0.95  PZIN/E/0.95-1.1  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 36520              NaN              NaN              NaN              NaN
# 36521              NaN              NaN              NaN              NaN
# 36522              NaN              NaN              NaN              NaN
# 36523              NaN              NaN              NaN              NaN
# 36524              NaN              NaN              NaN              NaN
#
#        PZIN/E/1.1-1.25  PZIN/E/1.25-1.4  PZIN/E/1.4-1.55  PZIN/E/1.55-1.7  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 36520              NaN              NaN              NaN              NaN
# 36521              NaN              NaN              NaN              NaN
# 36522              NaN              NaN              NaN              NaN
# 36523              NaN              NaN              NaN              NaN
# 36524              NaN              NaN              NaN              NaN
#
#        PZIN/E/1.7-1.85  PZIN/E/1.85-2.0
# 0                  NaN              NaN
# 1                  NaN              NaN
# 2                  NaN              NaN
# 3                  NaN              NaN
# 4                  NaN              NaN
# ...                ...              ...
# 36520              NaN              NaN
# 36521              NaN              NaN
# 36522              NaN              NaN
# 36523              NaN              NaN
# 36524              NaN              NaN
#
# [36525 rows x 547 columns]

# %% [markdown]
# # Clean Data

# %%
#The original scripts generate 25 data points per day, with midnight occuring twice.
#Since the scripts take over 3 weeks to run in completion, the extra data point will be removed at this point
#The second midnight will be removed, i.e. the one that comes after 2300hrs of any day

datetimecol = df.columns[0]
#print(df[datetimecol])

df['date'] = df[datetimecol].dt.date  #extract date
df['time'] = df[datetimecol].dt.time  #eextract time

rows_to_keep = []

for date in df['date'].unique():
    daily_df = df[df['date'] == date]
    mask_midnight = daily_df['time'] == pd.Timestamp("00:00:00").time() #boolean mask to identify midnights
    
    #mark rows which are midnight and second occurences as TRUE and remove them with bitwise NOT (~)
    if mask_midnight.sum() > 1: #more than one midnight
        #keep the first midnight and remove the second
        daily_df = daily_df[~(mask_midnight & daily_df.duplicated(subset=['date', 'time'], keep='first'))]

    rows_to_keep.append(daily_df)
    
df_cleaned = pd.concat(rows_to_keep)

df_cleaned.drop(columns=['date', 'time'], inplace=True) #drop the columns that were used to help extract the right dates

df_cleaned.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\erika\AppData\Local\Temp\ipykernel_14164\2376635103.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['date'] = df[datetimecol].dt.date  #extract date
# C:\Users\erika\AppData\Local\Temp\ipykernel_14164\2376635103.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['time'] = df[datetimecol].dt.time  #eextract time

# %%
print(df_cleaned)
# Out:
#                         index//  CAVT/Z/0.05-0.2  CAVT/Z/0.2-0.35  \
# 0     2018-01-01 00:00:00+00:00     8.815104e-08     3.130537e-07
# 1     2018-01-01 01:00:00+00:00     9.075963e-08     2.701870e-07
# 2     2018-01-01 02:00:00+00:00     8.520208e-08     2.473702e-07
# 3     2018-01-01 03:00:00+00:00     9.375001e-08     2.212960e-07
# 4     2018-01-01 04:00:00+00:00     8.792392e-08     2.167006e-07
# ...                         ...              ...              ...
# 35060 2020-12-31 19:00:00+00:00     8.597725e-08     5.494857e-07
# 35061 2020-12-31 20:00:00+00:00     8.805159e-08     5.173107e-07
# 35062 2020-12-31 21:00:00+00:00     8.122070e-08     5.236413e-07
# 35063 2020-12-31 22:00:00+00:00     7.401806e-08     4.866576e-07
# 35064 2020-12-31 23:00:00+00:00     7.629750e-08     5.090513e-07
#
#        CAVT/Z/0.35-0.5  CAVT/Z/0.5-0.65  CAVT/Z/0.65-0.8  CAVT/Z/0.8-0.95  \
# 0         3.858233e-07     1.872133e-07     8.724746e-08     5.200551e-08
# 1         3.621845e-07     1.733868e-07     8.228034e-08     6.319814e-08
# 2         3.362727e-07     1.771020e-07     8.291564e-08     5.781828e-08
# 3         2.984257e-07     1.629494e-07     8.144139e-08     5.942720e-08
# 4         2.813728e-07     1.555011e-07     9.039725e-08     6.847554e-08
# ...                ...              ...              ...              ...
# 35060     5.179527e-07     2.628983e-07     1.603441e-07     1.026380e-07
# 35061     4.951484e-07     2.734449e-07     1.621017e-07     1.040141e-07
# 35062     5.062911e-07     2.495162e-07     1.616080e-07     1.000351e-07
# 35063     4.634472e-07     2.445945e-07     1.569378e-07     9.904596e-08
# 35064     4.706459e-07     2.428860e-07     1.578281e-07     1.016258e-07
#
#        CAVT/Z/0.95-1.1  CAVT/Z/1.1-1.25  CAVT/Z/1.25-1.4  ...  \
# 0         4.367755e-08     3.129343e-08     2.224997e-08  ...
# 1         5.388271e-08     3.041222e-08     2.066138e-08  ...
# 2         4.418179e-08     2.699017e-08     1.816186e-08  ...
# 3         5.077291e-08     3.026113e-08     2.043267e-08  ...
# 4         5.700360e-08     3.107457e-08     2.002801e-08  ...
# ...                ...              ...              ...  ...
# 35060     6.991068e-08     4.515570e-08     3.529937e-08  ...
# 35061     7.473947e-08     5.398481e-08     4.164952e-08  ...
# 35062     7.514235e-08     6.245469e-08     4.425945e-08  ...
# 35063     7.602344e-08     5.961127e-08     4.892937e-08  ...
# 35064     8.924231e-08     6.840149e-08     4.805512e-08  ...
#
#        PZIN/E/0.5-0.65  PZIN/E/0.65-0.8  PZIN/E/0.8-0.95  PZIN/E/0.95-1.1  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 35060              NaN              NaN              NaN              NaN
# 35061              NaN              NaN              NaN              NaN
# 35062              NaN              NaN              NaN              NaN
# 35063              NaN              NaN              NaN              NaN
# 35064              NaN              NaN              NaN              NaN
#
#        PZIN/E/1.1-1.25  PZIN/E/1.25-1.4  PZIN/E/1.4-1.55  PZIN/E/1.55-1.7  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 35060              NaN              NaN              NaN              NaN
# 35061              NaN              NaN              NaN              NaN
# 35062              NaN              NaN              NaN              NaN
# 35063              NaN              NaN              NaN              NaN
# 35064              NaN              NaN              NaN              NaN
#
#        PZIN/E/1.7-1.85  PZIN/E/1.85-2.0
# 0                  NaN              NaN
# 1                  NaN              NaN
# 2                  NaN              NaN
# 3                  NaN              NaN
# 4                  NaN              NaN
# ...                ...              ...
# 35060              NaN              NaN
# 35061              NaN              NaN
# 35062              NaN              NaN
# 35063              NaN              NaN
# 35064              NaN              NaN
#
# [35065 rows x 547 columns]

# %%
df_cleaned = df_cleaned.sort_values(by=df_cleaned.columns[0],ascending=True) #sort chronologically
df_cleaned = df_cleaned.drop(df_cleaned.index[-1]) #drop the last row since it contains out of range data
df_cleaned.reset_index(drop=True, inplace=True) #reindex and replace idx column with new

# %%
print(df_cleaned)
# Out:
#                         index//  CAVT/Z/0.05-0.2  CAVT/Z/0.2-0.35  \
# 0     2018-01-01 00:00:00+00:00     8.815104e-08     3.130537e-07
# 1     2018-01-01 01:00:00+00:00     9.075963e-08     2.701870e-07
# 2     2018-01-01 02:00:00+00:00     8.520208e-08     2.473702e-07
# 3     2018-01-01 03:00:00+00:00     9.375001e-08     2.212960e-07
# 4     2018-01-01 04:00:00+00:00     8.792392e-08     2.167006e-07
# ...                         ...              ...              ...
# 35059 2021-12-31 19:00:00+00:00     1.602309e-08     5.449989e-08
# 35060 2021-12-31 20:00:00+00:00     1.644139e-08     5.304811e-08
# 35061 2021-12-31 21:00:00+00:00     1.666800e-08     5.008145e-08
# 35062 2021-12-31 22:00:00+00:00     1.740354e-08     4.722499e-08
# 35063 2021-12-31 23:00:00+00:00     1.748172e-08     4.882969e-08
#
#        CAVT/Z/0.35-0.5  CAVT/Z/0.5-0.65  CAVT/Z/0.65-0.8  CAVT/Z/0.8-0.95  \
# 0         3.858233e-07     1.872133e-07     8.724746e-08     5.200551e-08
# 1         3.621845e-07     1.733868e-07     8.228034e-08     6.319814e-08
# 2         3.362727e-07     1.771020e-07     8.291564e-08     5.781828e-08
# 3         2.984257e-07     1.629494e-07     8.144139e-08     5.942720e-08
# 4         2.813728e-07     1.555011e-07     9.039725e-08     6.847554e-08
# ...                ...              ...              ...              ...
# 35059     7.997935e-08     4.340312e-08     1.927715e-08     1.139608e-08
# 35060     7.691962e-08     4.267872e-08     1.882171e-08     1.231352e-08
# 35061     7.438536e-08     4.333015e-08     1.981937e-08     1.266816e-08
# 35062     7.874852e-08     4.497771e-08     1.882019e-08     1.209261e-08
# 35063     7.946408e-08     4.293058e-08     1.800177e-08     1.285510e-08
#
#        CAVT/Z/0.95-1.1  CAVT/Z/1.1-1.25  CAVT/Z/1.25-1.4  ...  \
# 0         4.367755e-08     3.129343e-08     2.224997e-08  ...
# 1         5.388271e-08     3.041222e-08     2.066138e-08  ...
# 2         4.418179e-08     2.699017e-08     1.816186e-08  ...
# 3         5.077291e-08     3.026113e-08     2.043267e-08  ...
# 4         5.700360e-08     3.107457e-08     2.002801e-08  ...
# ...                ...              ...              ...  ...
# 35059     8.445383e-09     6.027065e-09     5.257106e-09  ...
# 35060     9.246586e-09     6.785809e-09     5.398019e-09  ...
# 35061     9.331962e-09     6.462259e-09     4.812072e-09  ...
# 35062     8.871868e-09     6.503539e-09     4.892636e-09  ...
# 35063     9.685400e-09     6.904095e-09     5.325586e-09  ...
#
#        PZIN/E/0.5-0.65  PZIN/E/0.65-0.8  PZIN/E/0.8-0.95  PZIN/E/0.95-1.1  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 35059     4.536673e-07     3.065562e-07     2.779132e-07     2.222176e-07
# 35060     4.355292e-07     3.068167e-07     2.725549e-07     2.145709e-07
# 35061     4.448113e-07     3.177174e-07     2.836231e-07     2.099572e-07
# 35062     4.269581e-07     2.975468e-07     2.577635e-07     2.097015e-07
# 35063     3.899481e-07     2.787030e-07     2.594799e-07     2.013037e-07
#
#        PZIN/E/1.1-1.25  PZIN/E/1.25-1.4  PZIN/E/1.4-1.55  PZIN/E/1.55-1.7  \
# 0                  NaN              NaN              NaN              NaN
# 1                  NaN              NaN              NaN              NaN
# 2                  NaN              NaN              NaN              NaN
# 3                  NaN              NaN              NaN              NaN
# 4                  NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 35059     1.518212e-07     9.830256e-08     7.991248e-08     6.107685e-08
# 35060     1.464113e-07     9.841949e-08     7.596299e-08     5.947551e-08
# 35061     1.417773e-07     9.737431e-08     7.766383e-08     5.981378e-08
# 35062     1.458563e-07     9.552045e-08     7.548700e-08     6.108724e-08
# 35063     1.363224e-07     9.080615e-08     7.823698e-08     5.898212e-08
#
#        PZIN/E/1.7-1.85  PZIN/E/1.85-2.0
# 0                  NaN              NaN
# 1                  NaN              NaN
# 2                  NaN              NaN
# 3                  NaN              NaN
# 4                  NaN              NaN
# ...                ...              ...
# 35059     4.873257e-08     3.752280e-08
# 35060     4.526102e-08     3.524484e-08
# 35061     4.732481e-08     3.595792e-08
# 35062     4.630032e-08     3.577739e-08
# 35063     4.564301e-08     3.490117e-08
#
# [35064 rows x 547 columns]

# %% [markdown]
# # Save Data

# %%
#Export dataset to parquet format - suitable for large data

df_cleaned.to_parquet('Processed Data/RMS_data.parquet', engine='pyarrow', compression='snappy')

print("Data saved to Processed Data/RMS_data.parquet")
# Out:
# Data saved to Processed Data/RMS_data.parquet
