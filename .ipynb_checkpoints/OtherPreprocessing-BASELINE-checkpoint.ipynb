# %% [markdown]
# This notebook contains the remaining preprocessing functions that must be applied to the sea and seism data before training any machine learning models, in line with Minio et al.'s code.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from obspy.core.utcdatetime import UTCDateTime

# %% [markdown]
# # Clean Sea Data

# %%
#Load data from parquet files

path_lat = "Processed Data/SEA_data_lat.parquet"
path_lon = "Processed Data/SEA_data_lon.parquet"
path_Y = "Processed Data/SEA_data_Y.parquet"
path_time = "Processed Data/SEA_data_time.parquet"

df_lat = pd.read_parquet(path_lat)
df_lon = pd.read_parquet(path_lon)
df_Y = pd.read_parquet(path_Y)
df_time = pd.read_parquet(path_time)

# %%
print(df_Y.shape)
# Out:
# (35064, 9964)

# %%
nan_columns = df_Y.columns[df_Y.isna().all()]
print("Columns with all NaN values:", nan_columns.tolist())

#print(f"Number of NaN columns: {len(nan_columns)}")
# Out:
# Columns with all NaN values: [982, 1086, 1087, 1088, 1875, 1876, 1978, 1979, 1980, 1981, 1982, 2083, 2084, 2085, 2086, 2087, 2088, 2189, 2190, 2191, 2192, 2193, 2295, 2296, 2398, 2399, 2400, 2401, 2504, 2505, 2506, 4009, 4114, 4115, 4116, 4212, 4213, 4214, 4215, 4216, 4217, 4218, 4219, 4220, 4221, 4252, 4253, 4254, 4316, 4317, 4318, 4319, 4320, 4321, 4322, 4323, 4324, 4325, 4326, 4327, 4358, 4359, 4418, 4419, 4420, 4421, 4422, 4423, 4424, 4425, 4426, 4427, 4428, 4429, 4430, 4431, 4432, 4433, 4524, 4525, 4526, 4527, 4528, 4529, 4530, 4531, 4532, 4533, 4534, 4535, 4536, 4537, 4538, 4539, 4630, 4631, 4632, 4633, 4634, 4635, 4636, 4637, 4638, 4639, 4640, 4641, 4642, 4643, 4644, 4645, 4646, 4735, 4736, 4737, 4738, 4739, 4740, 4741, 4742, 4743, 4744, 4745, 4746, 4747, 4748, 4749, 4750, 4751, 4752, 4753, 4840, 4841, 4842, 4843, 4844, 4845, 4846, 4847, 4848, 4849, 4850, 4851, 4852, 4853, 4854, 4855, 4856, 4857, 4858, 4859, 4860, 4861, 4945, 4946, 4947, 4948, 4949, 4950, 4951, 4952, 4953, 4954, 4955, 4956, 4957, 4958, 4959, 4960, 4961, 4962, 4963, 4964, 4965, 4966, 4967, 4968, 5049, 5050, 5051, 5052, 5053, 5054, 5055, 5056, 5057, 5058, 5059, 5060, 5061, 5062, 5063, 5064, 5065, 5066, 5067, 5068, 5069, 5070, 5071, 5072, 5073, 5074, 5147, 5148, 5149, 5150, 5151, 5152, 5153, 5154, 5155, 5156, 5157, 5158, 5159, 5160, 5161, 5162, 5163, 5164, 5165, 5166, 5167, 5168, 5169, 5170, 5171, 5172, 5173, 5174, 5175, 5176, 5177, 5178, 5179, 5180, 5249, 5250, 5251, 5252, 5253, 5254, 5255, 5256, 5257, 5258, 5259, 5260, 5261, 5262, 5263, 5264, 5265, 5266, 5267, 5268, 5269, 5270, 5271, 5272, 5273, 5274, 5275, 5276, 5277, 5278, 5279, 5280, 5281, 5282, 5283, 5284, 5353
# %%
#Example of NaN column
#print(df_Y[982].tolist())

# %%
#Find latitudes and longitudes for which there is no sea data (columns of nans)

num_lat = df_lat.shape[0]
num_lon = df_lon.shape[1]

nan_lat_lon = []

for col_index in nan_columns:
    lat_index = num_lat - 1 - (col_index // num_lon) #get row index (latitude). -1 ensures correct alignment with map
    lon_index = col_index % num_lon #get column index (longitude)

    latitude = df_lat.iloc[lat_index, lon_index]
    longitude = df_lon.iloc[lat_index, lon_index]

    nan_lat_lon.append((latitude, longitude))

#print(nan_lat_lon)

# %%
#Visualise 1 day of data on a map
Y = df_Y[0:24]
lat = np.array(df_lat).squeeze()
lon = np.array(df_lon).squeeze()

#Extract unique latitude and longitude values from the 2D arrays
lat = np.unique(lat[:, 0]) #Use the first column to extract unique latitudes
lon = np.unique(lon[0, :]) #Use the first row to extract unique longitudes

#Compute time-averaged data. ignoring nans. result of a whole column of nans is nan
Y_avg = np.nanmean(Y, axis=0)
Y_avg_reshaped = Y_avg.reshape(len(lat), len(lon))

#Create the heatmap
plt.figure(figsize=(10, 8))
plt.contourf(lon, lat, Y_avg_reshaped, levels=100, cmap='viridis')
plt.colorbar(label='Time-averaged value')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Time-averaged Spatial Distribution (Corrected Orientation)')
plt.show()
# Out:
# C:\Users\erika\AppData\Local\Temp\ipykernel_5988\3927807446.py:11: RuntimeWarning: Mean of empty slice
#   Y_avg = np.nanmean(Y, axis=0)

# %%
#Visualise 2021 H2 data to see impact of Apollo in October 2021

#get data of approx the last six months in the dataset hourly, for one location
Y_2021H2 = df_Y.iloc[-(6*30*24):,3600]

time_2021H2 = df_time.iloc[-(6*30*24):,0]

plt.figure(figsize=(10, 6))
plt.plot(time_2021H2, Y_2021H2, label='Y_2021H2')

# %%
num_lat = df_lat.shape[0]
num_lon = df_lon.shape[1]

col_index = 3600

lat_index = col_index // num_lon #get row index (latitude)
lon_index = col_index % num_lon #get column index (longitude)

latitude = df_lat.iloc[lat_index, lon_index]
longitude = df_lon.iloc[lat_index, lon_index]
print(latitude,longitude)
# Out:
# 37.604168 15.708336

# %%
#Combining the data such that it has format date, (lat,lon) in the header row for 7,632 lat and lon pairs and 35,064 rows.
# the data won't change much, the header row will - to include lat,lon
lat_unique = df_lat.iloc[:,0].values.flatten() #take the first column of df_lat to get the unique values
lat_unique = np.sort(lat_unique) #sort smallest to largest
lon_unique = df_lon.iloc[0,:].values.flatten() #take the first row of df_lon to get the unique values

# %%
lat_unique
# Out:
# array([35.104168, 35.145836, 35.1875  , 35.229168, 35.270836, 35.3125  ,
#        35.354168, 35.395836, 35.4375  , 35.479168, 35.520836, 35.5625  ,
#        35.604168, 35.645836, 35.6875  , 35.729168, 35.770836, 35.8125  ,
#        35.854168, 35.895836, 35.9375  , 35.979168, 36.020836, 36.0625  ,
#        36.104168, 36.145836, 36.1875  , 36.229168, 36.270836, 36.3125  ,
#        36.354168, 36.395836, 36.4375  , 36.479168, 36.520836, 36.5625  ,
#        36.604168, 36.645836, 36.6875  , 36.729168, 36.770836, 36.8125  ,
#        36.854168, 36.895836, 36.9375  , 36.979168, 37.020836, 37.0625  ,
#        37.104168, 37.145836, 37.1875  , 37.229168, 37.270836, 37.3125  ,
#        37.354168, 37.395836, 37.4375  , 37.479168, 37.520836, 37.5625  ,
#        37.604168, 37.645836, 37.6875  , 37.729168, 37.770836, 37.8125  ,
#        37.854168, 37.895836, 37.9375  , 37.979168, 38.020836, 38.0625  ,
#        38.104168, 38.145836, 38.1875  , 38.229168, 38.270836, 38.3125  ,
#        38.354168, 38.395836, 38.4375  , 38.479168, 38.520836, 38.5625  ,
#        38.604168, 38.645836, 38.6875  , 38.729168, 38.770836, 38.8125  ,
#        38.854168, 38.895836, 38.9375  , 38.979168], dtype=float32)

# %%
lon_unique
# Out:
# array([11.458334, 11.5     , 11.541668, 11.583334, 11.625   , 11.666668,
#        11.708334, 11.75    , 11.791668, 11.833334, 11.875   , 11.916668,
#        11.958334, 12.      , 12.041668, 12.083334, 12.125   , 12.166668,
#        12.208334, 12.25    , 12.291668, 12.333334, 12.375   , 12.416668,
#        12.458334, 12.5     , 12.541668, 12.583334, 12.625   , 12.666668,
#        12.708334, 12.75    , 12.791668, 12.833334, 12.875   , 12.916668,
#        12.958334, 13.      , 13.041668, 13.083334, 13.125   , 13.166668,
#        13.208334, 13.25    , 13.291668, 13.333334, 13.375   , 13.416668,
#        13.458334, 13.5     , 13.541668, 13.583334, 13.625   , 13.666668,
#        13.708334, 13.75    , 13.791668, 13.833334, 13.875   , 13.916668,
#        13.958336, 14.      , 14.041668, 14.083336, 14.125   , 14.166668,
#        14.208336, 14.25    , 14.291668, 14.333336, 14.375   , 14.416668,
#        14.458336, 14.5     , 14.541668, 14.583336, 14.625   , 14.666668,
#        14.708336, 14.75    , 14.791668, 14.833336, 14.875   , 14.916668,
#        14.958336, 15.      , 15.041668, 15.083336, 15.125   , 15.166668,
#        15.208336, 15.25    , 15.291668, 15.333336, 15.375   , 15.416668,
#        15.458336, 15.5     , 15.541668, 15.583336, 15.625   , 15.666668,
#        15.708336, 15.75    , 15.791668, 15.833336], dtype=float32)

# %%
lat_lon_pairs = []

for i in range(len(lat_unique)):
    for j in range(len(lon_unique)):
        lat_lon_pairs.append(f"({lat_unique[i]}, {lon_unique[j]})")

df_sea = pd.DataFrame(df_Y)

df_sea.columns = lat_lon_pairs

df_sea['time'] = df_time #add time
df_sea.set_index('time', inplace=True) #set it as index

# %%
df_sea.head()
# Out:
#                      (35.10416793823242, 11.458333969116211)  \
# time
# 2018-01-01 00:00:00                                    0.637
# 2018-01-01 01:00:00                                    0.637
# 2018-01-01 02:00:00                                    0.623
# 2018-01-01 03:00:00                                    0.602
# 2018-01-01 04:00:00                                    0.567
#
#                      (35.10416793823242, 11.5)  \
# time
# 2018-01-01 00:00:00                      0.650
# 2018-01-01 01:00:00                      0.655
# 2018-01-01 02:00:00                      0.643
#                      (38.97916793823242, 15.583335876464844)  \
# time
# 2018-01-01 00:00:00                                    0.990
# 2018-01-01 01:00:00                                    0.962
# 2018-01-01 02:00:00                                    0.936
# 2018-01-01 03:00:00                                    0.912
# 2018-01-01 04:00:00                                    0.888
#
#                      (38.97916793823242, 15.625)  \
# time
# 2018-01-01 00:00:00                        0.987
# 2018-01-01 01:00:00                        0.960
# 2018-01-01 02:00:00                        0.934
# 2018-01-01 03:00:00                        0.910
# 2018-01-01 04:00:00                        0.887
#
#                      (38.97916793823242, 15.666667938232422)  \
# time
# 2018-01-01 00:00:00                                    0.984
# 2018-01-01 01:00:00                                    0.958
# 2018-01-01 02:00:00                                    0.933
# 2018-01-01 03:00:00                                    0.908
# 2018-01-01 04:00:00                                    0.885
#
#                      (38.97916793823242, 15.708335876464844)  \
# time
# 2018-01-01 00:00:00                                    0.980
# 2018-01-01 01:00:00                                    0.957
# 2018-01-01 02:00:00                                    0.931
# 2018-01-01 03:00:00                                    0.907
# 2018-01-01 04:00:00                                    0.884
#
#                      (38.97916793823242, 15.75)  \
# time
# 2018-01-01 00:00:00                       0.975
# 2018-01-01 01:00:00                       0.954
# 2018-01-01 02:00:00                       0.929
# 2018-01-01 03:00:00                       0.905
# 2018-01-01 04:00:00                       0.883
#
#                      (38.97916793823242, 15.791667938232422)  \
# time
# 2018-01-01 00:00:00                                    0.970
# 2018-01-01 01:00:00                                    0.952
# 2018-01-01 02:00:00                                    0.927
# 2018-01-01 03:00:00                                    0.904
# 2018-01-01 04:00:00                                    0.881
#
#                      (38.97916793823242, 15.833335876464844)
# time
# 2018-01-01 00:00:00                                    0.966
# 2018-01-01 01:00:00                                    0.950
# 2018-01-01 02:00:00                                    0.926
# 2018-01-01 03:00:00                                    0.902
# 2018-01-01 04:00:00                                    0.880
#
# [5 rows x 9964 columns]

# %%
df_sea.shape
# Out:
# (35064, 9964)

# %%
df_sea = df_sea.dropna(axis=1, how='all')
df_sea.shape
# Out:
# (35064, 8355)

# %% [markdown]
# # Clean RMS Data

# %%
#From config file of Minio

# threshold to delete ambigous rms values  
rms_thr = 1e-9 

# maximum number of nan for each column of RMS dataframe  
row_thr = 5000

# %%
#Load data from parquet files

path_rms = "Processed Data/RMS_data.parquet"
df_rms = pd.read_parquet(path_rms)

# %%
#Apart from the date column (first column), replace anything below the rms threshold with nan
df_rms.iloc[:, 1:] = df_rms.iloc[:, 1:].where(df_rms.iloc[:, 1:] >= rms_thr, np.nan)

# %%
#drop columns with too many missing values based on the row_thr threshold
cols_to_drop = df_rms.columns[df_rms.isnull().sum(axis=0) > row_thr]
print(len(cols_to_drop))
df_rms.drop(columns=cols_to_drop, inplace=True)
# Out:
# 216

# %%
#interpolate remaining NaN values in the DataFrame
df_rms.interpolate(limit_direction='both', inplace=True)

# %%
print(df_rms)
# Out:
#                         index//  MMGO/Z/0.05-0.2  MMGO/Z/0.2-0.35  \
# 0     2018-01-01 00:00:00+00:00     4.045681e-07     3.843778e-07
N/Z/1.55-1.7', 'SOLUN/Z/1.7-1.85', 'SOLUN/Z/1.85-2.0', 'CSLB/Z/0.05-0.2', 'CSLB/Z/0.2-0.35', 'CSLB/Z/0.35-0.5', 'CSLB/Z/0.5-0.65', 'CSLB/Z/0.65-0.8', 'CSLB/Z/0.8-0.95', 'CSLB/Z/0.95-1.1', 'CSLB/Z/1.1-1.25', 'CSLB/Z/1.25-1.4', 'CSLB/Z/1.4-1.55', 'MUCR/Z/0.05-0.2', 'MUCR/Z/0.2-0.35', 'MUCR/Z/0.35-0.5', 'MUCR/Z/0.5-0.65', 'MUCR/Z/0.65-0.8', 'MUCR/Z/0.8-0.95', 'MUCR/Z/0.95-1.1', 'MUCR/Z/1.1-1.25', 'MUCR/Z/1.25-1.4', 'MUCR/Z/1.4-1.55', 'MUCR/Z/1.55-1.7', 'MUCR/Z/1.7-1.85', 'MUCR/Z/1.85-2.0', 'AIO/Z/0.05-0.2', 'AIO/Z/0.2-0.35', 'AIO/Z/0.35-0.5', 'AIO/Z/0.5-0.65', 'AIO/Z/0.65-0.8', 'AIO/Z/0.8-0.95', 'AIO/Z/0.95-1.1', 'AIO/Z/1.1-1.25', 'AIO/Z/1.25-1.4', 'AIO/Z/1.4-1.55', 'AIO/Z/1.55-1.7', 'AIO/Z/1.7-1.85', 'AIO/Z/1.85-2.0', 'MSDA/Z/0.05-0.2', 'MSDA/Z/0.2-0.35', 'MSDA/Z/0.35-0.5', 'MSDA/Z/0.5-0.65', 'MSDA/Z/0.65-0.8', 'MSDA/Z/0.8-0.95', 'MSDA/Z/0.95-1.1', 'MSDA/Z/1.1-1.25', 'MSDA/Z/1.25-1.4', 'MSDA/Z/1.4-1.55', 'MSDA/Z/1.55-1.7', 'MSDA/Z/1.7-1.85', 'MSDA/Z/1.85-2.0', 'WDD/Z/0.05-0.2', 'WDD/Z/0.2-0.35', 'WDD/Z/0.35-0.5', 'WDD/Z/0.5-0.65', 'WDD/Z/0.65-0.8', 'WDD/Z/0.8-0.95', 'WDD/Z/0.95-1.1', 'WDD/Z/1.1-1.25', 'WDD/Z/1.25-1.4', 'WDD/Z/1.4-1.55', 'WDD/Z/1.55-1.7', 'WDD/Z/1.7-1.85', 'WDD/Z/1.85-2.0', 'MMGO/N/0.05-0.2', 'MMGO/N/0.2-0.35', 'MMGO/N/0.35-0.5', 'MMGO/N/0.5-0.65', 'MMGO/N/0.65-0.8', 'MMGO/N/0.8-0.95', 'MMGO/N/0.95-1.1', 'MMGO/N/1.1-1.25', 'MMGO/N/1.25-1.4', 'MMGO/N/1.4-1.55', 'MMGO/N/1.55-1.7', 'MMGO/N/1.7-1.85', 'MMGO/N/1.85-2.0', 'HAGA/N/0.05-0.2', 'HAGA/N/0.2-0.35', 'HAGA/N/0.35-0.5', 'HAGA/N/0.5-0.65', 'HAGA/N/0.65-0.8', 'HAGA/N/0.8-0.95', 'HAGA/N/0.95-1.1', 'HAGA/N/1.1-1.25', 'HAGA/N/1.25-1.4',
# %% [markdown]
# Before applying the skewness correction, one should look at the distribution of the data to understand if there are many small values (for example), that merit skewness correction to be applied. Using a skewness limit of 0.7, the first column MMGO/Z/0.05-0.2 would require correction. So we can investigate that to udnerstnad better.

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_rms.iloc[:, 1], kde=True, color='blue', edgecolor='black')
plt.title(f'Distribution of {df_rms.columns[1]}')
plt.xlabel(df_rms.columns[1])
plt.show()

# %% [markdown]
# While the data does show some skewness, RF and LGB are not affected by skewness. Therefore, we can skip skewness to shorten the data transformation pipeline that we would need to apply to new data points once the models are trained and in-use too.

# %%
#skewness limit used to apply box-cox transformation    
skew_limit = 0.7

# %%
clean_df_rms = df_rms.copy()
idx_sks = []
lmbda = []
alpha = []

# %%
#check skewness and apply Box-Cox transformation where necessary
for icol, col in enumerate(df_rms.columns[1:], start=1):
    skewness = df_rms[col].skew()
    
    #check if skewness exceeds the threshold
    if abs(skewness) > skew_limit:
        #apply the box-cox transformation and save results
        transformed_data, lambda_value, conf_interval = stats.boxcox(df_rms[col].dropna(), alpha=True)
        clean_df_rms.loc[df_rms[col].notna(), col] = transformed_data
        
        #append transformation information
        idx_sks.append(icol)
        lmbda.append(lambda_value)
        alpha.append(conf_interval)
        print(f"Column {col}: Skewness corrected with lambda = {lambda_value}")

print("Skewness correction completed.")
# Out:
# Column MMGO/Z/0.05-0.2: Skewness corrected with lambda = -0.12776762852835324
# Column MMGO/Z/0.2-0.35: Skewness corrected with lambda = -0.17610724959451166
# Column MMGO/Z/0.35-0.5: Skewness corrected with lambda = -0.07644634922569854
# Column MMGO/Z/0.5-0.65: Skewness corrected with lambda = -0.0966932712862411
# Column MMGO/Z/0.65-0.8: Skewness corrected with lambda = -0.12928675209931637
# Column MMGO/Z/0.8-0.95: Skewness corrected with lambda = -0.15132697729858116
# Column MMGO/Z/0.95-1.1: Skewness corrected with lambda = -0.18106303327192944
# Column MMGO/Z/1.1-1.25: Skewness corrected with lambda = -0.2149157517069175
# Column MMGO/Z/1.25-1.4: Skewness corrected with lambda = -0.22725225021289855
# Column MMGO/Z/1.4-1.55: Skewness corrected with lambda = -0.22590700653657503
# Column MMGO/Z/1.55-1.7: Skewness corrected with lambda = -0.24525002495166112
# Column MMGO/Z/1.7-1.85: Skewness corrected with lambda = -0.26920195806034275
# Column MMGO/Z/1.85-2.0: Skewness corrected with lambda = -0.2600888051843494
# Column HAGA/Z/0.05-0.2: Skewness corrected with lambda = -0.47316092784560876
# Column HAGA/Z/0.2-0.35: Skewness corrected with lambda = -0.34925899124863097
# Column HAGA/Z/0.35-0.5: Skewness corrected with lambda = 0.08001678401009864
# Column HAGA/Z/0.5-0.65: Skewness corrected with lambda = -0.001145024919115348
# Column HAGA/Z/0.65-0.8: Skewness corrected with lambda = -0.12844330350429667
# Column HAGA/Z/0.8-0.95: Skewness corrected with lambda = -0.09872670683741172
# Column HAGA/Z/0.95-1.1: Skewness corrected with lambda = -0.03957853368011191
# Column SOLUN/Z/0.05-0.2: Skewness corrected with lambda = -0.16406284281708663
# Column CSLB/Z/0.05-0.2: Skewness corrected with lambda = -0.2091162908431922
# Column MUCR/Z/0.05-0.2: Skewness corrected with lambda = -0.44988176375308375
# Column AIO/Z/0.05-0.2: Skewness corrected with lambda = -0.3755258034770323
# Column MSDA/Z/0.05-0.2: Skewness corrected with lambda = -0.48538468925980033
# Column MSDA/Z/0.2-0.35: Skewness corrected with lambda = -0.14064735724503447
# Column MSDA/Z/0.35-0.5: Skewness corrected with lambda = 0.11226323778419321
# Column MSDA/Z/0.5-0.65: Skewness corrected with lambda = 0.061732275097220166
# Column MSDA/Z/0.65-0.8: Skewness corrected with lambda = 0.02512381541015897
# Column MSDA/Z/0.8-0.95: Skewness corrected with lambda = 0.019427151591959006
# Column MSDA/Z/0.95-1.1: Skewness corrected with lambda = 0.01431834689270876
# Column MSDA/Z/1.1-1.25: Skewness corrected with lambda = 0.004396477141415733
# Column MSDA/Z/1.25-1.4: Skewness corrected with lambda = -0.014869537642748695
# Column MSDA/Z/1.4-1.55: Skewness corrected with lambda = -0.03241057352865303
# Column MSDA/Z/1.55-1.7: Skewness corrected with lambda = -0.06905721698115366
# Column MSDA/Z/1.7-1.85: Skewness corrected with lambda = -0.07855968975333065
# Column MSDA/Z/1.85-2.0: Skewness corrected with lambda = -0.10918654091871823
# Column MMGO/N/0.05-0.2: Skewness corrected with lambda = -0.23418754351967644
# Column MMGO/N/0.2-0.35: Skewness corrected with lambda = -0.043390281324074964
# Column MMGO/N/0.35-0.5: Skewness corrected with lambda = 0.168233601459409
# Column MMGO/N/0.5-0.65: Skewness corrected with lambda = -0.08146981050625962
# Column MMGO/N/0.65-0.8: Skewness corrected with lambda = -0.12304197014899054
# Column MMGO/N/0.8-0.95: Skewness corrected with lambda = 0.07367051205212902
# Column MMGO/N/0.95-1.1: Skewness corrected with lambda = -0.08942060880300085
# Column MMGO/N/1.1-1.25: Skewness corrected with lambda = -0.13572333647768015
# Column MMGO/N/1.25-1.4: Skewness corrected with lambda = 0.035833185977024264
# Column MMGO/N/1.4-1.55: Skewness corrected with lambda = -0.13969862735631933
# Column MMGO/N/1.55-1.7: Skewness corrected with lambda = -0.14894641601657937
# Column MMGO/N/1.7-1.85: Skewness corrected with lambda = 0.011887115490551131
# Column MMGO/N/1.85-2.0: Skewness corrected with lambda = -0.016092890337846104
# Column HAGA/N/0.05-0.2: Skewness corrected with lambda = -0.4586239003440559
# Column HAGA/N/0.2-0.35: Skewness corrected with lambda = -0.20727177355804283
# Column HAGA/N/0.35-0.5: Skewness corrected with lambda = 0.11597623593246909
# Column HAGA/N/0.5-0.65: Skewness corrected with lambda = 0.0011906316264031181
# Column HAGA/N/0.65-0.8: Skewness corrected with lambda = -0.13960180477646203
# Column HAGA/N/0.8-0.95: Skewness corrected with lambda = -0.10685635341560282
# Column HAGA/N/0.95-1.1: Skewness corrected with lambda = -0.06342278633025344
# Column HAGA/N/1.1-1.25: Skewness corrected with lambda = -0.05451533084208935
# Column HAGA/N/1.25-1.4: Skewness corrected with lambda = -0.0796786592659865
# Column SOLUN/N/0.05-0.2: Skewness corrected with lambda = -0.1616387626162109
# Column MUCR/N/0.05-0.2: Skewness corrected with lambda = -0.3916610271560443
# Column MSDA/N/0.05-0.2: Skewness corrected with lambda = -0.4182154771545566
# Column MSDA/N/0.2-0.35: Skewness corrected with lambda = -0.0628287392483378
# Column MSDA/N/0.35-0.5: Skewness corrected with lambda = 0.12431675267325619
# Column MSDA/N/0.5-0.65: Skewness corrected with lambda = 0.0682877930737453
# Column MSDA/N/0.65-0.8: Skewness corrected with lambda = 0.02070830139064633
# Column MSDA/N/0.8-0.95: Skewness corrected with lambda = 0.0034288999883223398
# Column MSDA/N/0.95-1.1: Skewness corrected with lambda = -0.009589751823906482
# Column MSDA/N/1.1-1.25: Skewness corrected with lambda = -0.027042317298876642
# Column MSDA/N/1.25-1.4: Skewness corrected with lambda = -0.036524183244447186
# Column MSDA/N/1.4-1.55: Skewness corrected with lambda = -0.05863994064053528
# Column MSDA/N/1.55-1.7: Skewness corrected with lambda = -0.0751966138004305
# Column MSDA/N/1.7-1.85: Skewness corrected with lambda = -0.07933205270463276
# Column MSDA/N/1.85-2.0: Skewness corrected with lambda = -0.10507189193140709
# Column HAGA/E/0.05-0.2: Skewness corrected with lambda = -0.44419932987906635
# Column HAGA/E/0.2-0.35: Skewness corrected with lambda = -0.2156650962296775
# Column HAGA/E/0.35-0.5: Skewness corrected with lambda = 0.11631286295162037
# Column HAGA/E/0.5-0.65: Skewness corrected with lambda = 0.00351163391971837
# Column HAGA/E/0.65-0.8: Skewness corrected with lambda = -0.12867414624399567
# Column SOLUN/E/0.05-0.2: Skewness corrected with lambda = -0.15948857568968947
# Column MSDA/E/0.05-0.2: Skewness corrected with lambda = -0.3725990137246566
# Column MSDA/E/0.2-0.35: Skewness corrected with lambda = -0.05945283549681223
# Column MSDA/E/0.35-0.5: Skewness corrected with lambda = 0.15977662007569146
# Column MSDA/E/0.5-0.65: Skewness corrected with lambda = 0.1124403921668091
# Column MSDA/E/0.65-0.8: Skewness corrected with lambda = 0.05747237428225275
# Column MSDA/E/0.8-0.95: Skewness corrected with lambda = 0.034260163435333175
# Column MSDA/E/0.95-1.1: Skewness corrected with lambda = 0.01989826057646186
# Column MSDA/E/1.1-1.25: Skewness corrected with lambda = -0.0011071884347723271
# Column MSDA/E/1.25-1.4: Skewness corrected with lambda = -0.010599192333171546
# Column MSDA/E/1.4-1.55: Skewness corrected with lambda = -0.03513502749430243
# Column MSDA/E/1.55-1.7: Skewness corrected with lambda = -0.07398833824905728
# Column MSDA/E/1.7-1.85: Skewness corrected with lambda = -0.11011929967832072
# Column MSDA/E/1.85-2.0: Skewness corrected with lambda = -0.1209641070479074
# Skewness correction completed.

# %% [markdown]
# # Earthquake Catalog

# %%
#cnvert start and end times to strings for query
starttime = UTCDateTime('2018-01-01 00:00:00')
endtime = UTCDateTime('2021-01-31 23:59:00')

# dataframe of earthquakes for past period    
eqCatalog= "https://earthquake.usgs.gov/fdsnws/event/1/query.csv"

# number of hours used to clean the dataset from earthquake influencev   
hours_del = float(2)

# Magnitude over-threshold for regional eartquakes   
MagMed = float(5.5) 

# Magnitude over-threshold for global eartquakes  
MagWorld = float(7)

# down-limit of latitude for Sicilian Channel Sea  
lat1 = float(35.10)

# up-limit of latitude for Sicilian Channel Sea     
lat2 = float(38.09) 

# down-limit of longitude for Sicilian Channel Sea  
lon1 = float(11.45)

# up-limit of longitude  for Sicilian Channel Sea    
lon2 = float(15.87)

# %%
starttime_str = starttime.strftime('%Y-%m-%dT%H:%M:%S')
endtime_str = endtime.strftime('%Y-%m-%dT%H:%M:%S')

#construct the query URL for earthquake data
query = (
    f"?starttime={starttime_str}&endtime={endtime_str}"
    f"&minmagnitude={MagMed}&orderby=time"
)
eq_url = eqCatalog + query

#load the earthquake catalog
eqs = pd.read_csv(eq_url)
print(f"Earthquake catalog loaded. Total entries: {len(eqs)}")
# Out:
# Earthquake catalog loaded. Total entries: 1369

# %%
#separate earthquakes into global and regional based on magnitude and location
eqs_world = eqs[
    (eqs['time'] >= starttime.strftime('%Y-%m-%dT%H:%M:%S')) &
    (eqs['time'] <= endtime.strftime('%Y-%m-%dT%H:%M:%S')) &
    (eqs['mag'] > MagWorld) &
    ((eqs['latitude'] < lat1) | (eqs['latitude'] > lat2) |
     (eqs['longitude'] < lon1) | (eqs['longitude'] > lon2))
]
eqs_region = eqs[
    (eqs['time'] >= starttime.strftime('%Y-%m-%dT%H:%M:%S')) &
    (eqs['time'] <= endtime.strftime('%Y-%m-%dT%H:%M:%S')) &
    (eqs['mag'] > MagMed) &
    (eqs['latitude'] >= lat1) & (eqs['latitude'] <= lat2) &
    (eqs['longitude'] >= lon1) & (eqs['longitude'] <= lon2)
]

print(f"Global earthquakes affecting data: {len(eqs_world)}")
print(f"Regional earthquakes affecting data: {len(eqs_region)}")
# Out:
# Global earthquakes affecting data: 30
# Regional earthquakes affecting data: 0

# %%
#combine earthquake times
affected_times = pd.concat([eqs_region['time'], eqs_world['time']])

if not affected_times.empty:
    for quake_time in affected_times:
        #convert earthquake time to datetime and calculate the time interval to delete
        time_start = pd.to_datetime(quake_time, utc=True)
        time_end = time_start + pd.to_timedelta(hours_del, unit='h')

        if df_sea.index.tz is None:
            df_sea.index = df_sea.index.tz_localize('UTC')

        #filter out rows within the earthquake time interval
        clean_df_sea = df_sea[(df_sea.index < time_start) | (df_sea.index > time_end)]
        clean_df_rms_2 = clean_df_rms[(clean_df_rms.iloc[:,0] < time_start) | (clean_df_rms.iloc[:,0] > time_end)]

    print("Data cleaned from earthquake influence.")
else:
    print("No significant earthquakes found. Data remains unchanged.")
# Out:
# Data cleaned from earthquake influence.

# %%
clean_df_sea.to_parquet('Processed Data/SEA_data_BASELINE.parquet', engine='pyarrow', compression='snappy')
clean_df_rms_2.to_parquet('Processed Data/RMS_data_BASELINE.parquet', engine='pyarrow', compression='snappy')
